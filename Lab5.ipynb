class1', 'Class1', 'Class1', 'Class1', 'Class1', 'Class1', 'Class1',
'Class1', 'Class1', 'Class1', 'Class1', 'Class1', 'Class1', 'Class1', 'Class1',
'Class1', 'Class1', 'Class1', 'Class1', 'Class1', 'Class1', 'Class1', 'Class1',
'Class1', 'Class2', 'Class2', 'Class2', 'Class2', 'Class2', 'Class2', 'Class2',
'Class2', 'Class2', 'Class2', 'Class2', 'Class2', 'Class2', 'Class2', 'Class2',
'Class2', 'Class2', 'Class2', 'Class2', 'Class2', 'Class2', 'Class2', 'Class2',
'Class2', 'Class3', 'Class3', 'Class3', 'Class3', 'Class3', 'Class3', 'Class3',
'Class3', 'Class3', 'Class3', 'Class3', 'Class3', 'Class3', 'Class3', 'Class3',
'Class3', 'Class3', 'Class3', 'Class3', 'Class3', 'Class3', 'Class3', 'Class3',
'Class3', 'Class4', 'Class4', 'Class4', 'Class4', 'Class4', 'Class4', 'Class4',
'Class4', 'Class4', 'Class4', 'Class4', 'Class4', 'Class4', 'Class4', 'Class4',
'Class4', 'Class4', 'Class4', 'Class4', 'Class4', 'Class4', 'Class4', 'Class4',
'Class4'] }

import numpy as np
import pandas as pd
#для выгрузки данных в R удобно преобразовать их в CSV c помощью Pandas
pd.DataFrame(data).to_csv("data.csv")
#просмотрим данные в виде pandas.DataFrame
pd.DataFrame(data).head(10)
# Out:
#           X         Y   class
# 0  2.280957  5.731744  Class1
# 1  2.194906  4.897826  Class1
# 2  1.365915  5.242757  Class1
# 3  2.718414  5.391525  Class1
# 4  2.259826  5.721533  Class1
# 5  1.377996  5.226707  Class1
# 6  2.035065  5.789225  Class1
# 7  4.256247  5.206455  Class1
# 8  2.693171  6.587894  Class1
# 9  1.605284  6.010473  Class1

# %%
#Выполнить предобработку данных согласно примеру:
#1.1 Разделение входных и выходных переменных
X = np.c_[data["X"], data["Y"]]

#1.2 Нормирование входных данных
xmin = np.min(X)
Xnorm = (X - xmin) / (np.max(X) - xmin)

#1.3 Кодирование выходных данных
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder(sparse_output = False)
Yenc = ohe.fit_transform( np.array(data["class"]).reshape(-1,1) )

print(f"Форма тензора X: {Xnorm.shape}")
print(f"Форма тензора Y: {Yenc.shape}")
# Out:
# Форма тензора X: (96, 2)
# Форма тензора Y: (96, 4)

# %%
#1.4 Разбиение данных на обучающий и тестовый наборы

from sklearn.model_selection import train_test_split
xTrain, xTest, yTrain, yTest = train_test_split(Xnorm, Yenc, test_size = 0.25)
print(f"Форма тензора Xtrain: {xTrain.shape}")
print(f"Форма тензора Ytrain: {yTrain.shape}")
print(f"Форма тензора Xtest: {xTest.shape}")
print(f"Форма тензора Ytest: {yTest.shape}")
# Out:
# Форма тензора Xtrain: (72, 2)
# Форма тензора Ytrain: (72, 4)
# Форма тензора Xtest: (24, 2)
# Форма тензора Ytest: (24, 4)

# %%
#2. С помощью Tensorflow или пакета Neuralnet в R построить нейронную сеть и обучить ее на обучающем наборе.

#построение нейронной сети с помощью Tensorflow
from keras.models import Sequential
from keras.layers import Dense
model = Sequential( [
 Dense( units = 4, activation = "relu", input_shape = (2,) ),
 Dense( units = 4, activation = "relu"),
 Dense( units = yTrain.shape[1], activation = "sigmoid" )
] )
model.compile( optimizer = "adam", loss = "categorical_crossentropy", metrics = ["categorical_accuracy"] )
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_9 (Dense)             (None, 4)                 12
#
#  dense_10 (Dense)            (None, 4)                 20
#
#  dense_11 (Dense)            (None, 4)                 20
#
# ...
# Total params: 52 (208.00 Byte)
# Trainable params: 52 (208.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#3. Вывести метрики процесса обучения нейронной сети

hist = model.fit( x = xTrain, y = yTrain, epochs = 200, batch_size = 10 )
import matplotlib.pyplot as plt
plt.plot(hist.history["loss"], label = "Loss")
plt.plot(hist.history["categorical_accuracy"], label = "accuracy")
plt.ylabel("Loss/Accuracy")
plt.xlabel("Epochs")
plt.legend()
plt.show()

#Для быстрого обучения нам потребовалось 200 эпох. На 177 эпохе модель достигла 95.83% точности,
#что и является её максимальным значением
# Out:
# Epoch 1/200
# 8/8 [==============================] - 2s 3ms/step - loss: 1.4152 - categorical_accuracy: 0.2639
# Epoch 2/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.4118 - categorical_accuracy: 0.2639
# Epoch 3/200
# 8/8 [==============================] - 0s 4ms/step - loss: 1.4093 - categorical_accuracy: 0.2639
# Epoch 4/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.4063 - categorical_accuracy: 0.2639
# Epoch 5/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.4037 - categorical_accuracy: 0.2639
# Epoch 6/200
# 8/8 [==============================] - 0s 4ms/step - loss: 1.4010 - categorical_accuracy: 0.2639
# Epoch 7/200
# 8/8 [==============================] - 0s 4ms/step - loss: 1.3984 - categorical_accuracy: 0.2639
# Epoch 8/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.3959 - categorical_accuracy: 0.2639
# Epoch 9/200
# ...

# %%
#оценка модели на тестовой выборке
model.evaluate(xTest, yTest)
#Точность модели - 100%
# Out:
# 1/1 [==============================] - 0s 256ms/step - loss: 0.2824 - categorical_accuracy: 1.0000
# [0.28241822123527527, 1.0]

# %%
#пройдем каждый пример тестовой выборки отдельно:
match = 0
for i in range(len(xTest)):
 x = xTest[i]
 y = yTest[i]

 yPred = model.predict( x.reshape(1,-1) )

 maxLogit = np.argmax(yPred)

 yAct = np.argmax(y)
 if maxLogit == yAct:
    match += 1
 print(f"Распознали как группу {ohe.categories_[0][maxLogit]} на самом деле: {ohe.categories_[0][yAct]}" )
print(f"Верно распознано {match} из {len(xTest)}")
# Out:
# 1/1 [==============================] - 0s 95ms/step
# Распознали как группу Class3 на самом деле: Class3
# 1/1 [==============================] - 0s 42ms/step
# Распознали как группу Class4 на самом деле: Class4
# 1/1 [==============================] - 0s 50ms/step
# Распознали как группу Class1 на самом деле: Class1
# 1/1 [==============================] - 0s 39ms/step
# Распознали как группу Class1 на самом деле: Class1
# 1/1 [==============================] - 0s 37ms/step
# Распознали как группу Class1 на самом деле: Class1
# 1/1 [==============================] - 0s 37ms/step
# Распознали как группу Class3 на самом деле: Class3
# 1/1 [==============================] - 0s 33ms/step
# Распознали как группу Class3 на самом деле: Class3
# 1/1 [==============================] - 0s 33ms/step
# Распознали как группу Class1 на самом деле: Class1
# 1/1 [==============================] - 0s 35ms/step
# Распознали как группу Class1 на самом деле: Class1
# ...

# %% [markdown]
# Модель правильно предсказала все значения на тестовой выборке, а значит что она достаточно хороша.
